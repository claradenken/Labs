# %%
name = str(input()) # I used the string function to get the name as user input
# Out:
# Clara

# %% [markdown]
# # Clara's holiday preferences

# %% [markdown]
# *The purpose of this notebook is to show you Clara's holiday preference*

# %% [markdown]
# This is **Clara** (playing the guitar at the Hard Rock Café Cologne with her guitar partner Max).

# %% [markdown]
# <div>
# <img src="attachment:Bildschirmfoto%202022-10-17%20um%2016.29.53.png" width="500" align="left"/>
# </div>

# %% [markdown]
# Clara's favorite travel destination is **Svalbard**.

# %% [markdown]
# <div>
# <img src="attachment:Bildschirmfoto%202022-10-17%20um%2016.32.46.png" align="left"/>
# </div>

# %% [markdown]
# In **Svalbard**, Clara likes to
# - go dog sledding
# - explore lost places
# - hike
